# %% [markdown]
# # Saudi Arabia Used Cars Dataset Analysis
#
# Analysis and exploration is most important goal in this project, Trying to find valuable information and insights from tthe Saudi Arabia used cars dataset.
#
# ![Used_Car_Brand-2.png](attachment:Used_Car_Brand-2.png)
#
# It can be clearly seen in the above figure, The Toyota cars dominated the best-seller in Saudi Arabia and be the most desirable car for selling and buying among about 58 . The second and the third used car barnd Huyndai and Ford with 970 and 800 respectively. Fourth and Fifth used car barnd places in the rank are Chevrolet and Nissan.
#
# This figure can give us a complete image of the most car brands owned by Saudi people.
